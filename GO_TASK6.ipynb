# %% [markdown]
# GOEDUHUB TECHNOLOGIES
# Reg no: GO_STP_7294

# %% [markdown]
# **Visualization using Python Matplotlib Library**
#
# ---

# %% [markdown]
# 1. Load the necessary package for plotting using pyplot from matplotlib. Example - Days(x-axis) represents 8
# days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as
# days and y axis label as car speed and put title Car Speed Measurement.
# Days=[1,2,3,4,5,6,7,8]
# Speed=[60,62,61,58,56,57,46,63]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Days=[1,2,3,4,5,6,7,8]
Speed=[60,62,61,58,56,57,46,63]
plt.plot(Days,Speed, color="Blue",linewidth=4)
plt.xlabel('Days')
plt.ylabel('Speed')
plt.show()

# %% [markdown]
# 2. Now to above car data apply some string formats like line style example green dotted line, marker shape like
# +, change markersize, markerface color etc.

# %%
Days=[1,2,3,4,5,6,7,8]
Speed=[60,62,61,58,56,57,46,63]
plt.plot(Days,Speed,color='green',linestyle="--",linewidth=4)
plt.scatter(Days,Speed, color="r", marker='+',linewidth=10)
plt.xlabel('Days')
plt.ylabel('Speed')
plt.show()

# %%
Days=[1,2,3,4,5,6,7,8]
Speed=[60,62,61,58,56,57,46,63]
plt.plot(Days,Speed,color='green',linestyle=":",linewidth=4)
plt.scatter(Days,Speed, color="b", marker='x',linewidth=10)
plt.xlabel('Days')
plt.ylabel('Speed')
plt.show()

# %% [markdown]
# 3. Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed
# in 8 days.
# days=[1,2,3,4,5,6,7,8]
# max_speed=[80,91,92,88,77,79,76,75]
# min_speed=[42,43,40,42,33,36,34,35]
# avg_speed=[46,58,57,56,40,42,41,36]

# %%
days=np.array([1,2,3,4,5,6,7,8])
max_speed=np.array([80,91,92,88,77,79,76,75])
min_speed=np.array([42,43,40,42,33,36,34,35])
avg_speed=np.array([46,58,57,56,40,42,41,36])
fig,(ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize = (10,10))
ax1.plot(days,max_speed,'--', linewidth=4)
ax1.scatter(days,max_speed,color='yellow',marker='p',linewidth=9)
ax1.set_title('Days vs Maximum Speed')
ax1.set_xlabel('Days')
fig,ax1.set_ylabel('Max Speed')
ax2.plot(days,min_speed, '-r', linewidth=3)
ax2.scatter(days,min_speed,color='green',marker='D',linewidth=12)
ax2.set_title('Days vs Minimum Speed')
ax2.set_xlabel('Days')
ax2.set_ylabel('Min Speed')
ax3.plot(days,avg_speed, '.-m', linewidth=6)
ax3.scatter(days,avg_speed,color='c',marker='x',linewidth=20)
ax3.set_title('Days vs Average Speed')
ax3.set_xlabel('Days')
ax2.set_ylabel('Average Speed')
fig.suptitle('Speed Plot', y = 1.00, fontsize=20)
fig.tight_layout()

# %% [markdown]
# 4. Plotting a basic sine graph by adding more features. Adding Multiple plots by
# Superimposition like cosine wave.

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x)
plt.figure(figsize=(12,3))
plt.plot(x,y,'b', linewidth = 3)
plt.plot(x,z,'--g',linewidth = 3)
plt.xlabel("Angle ")
plt.ylabel("Magnitude")
plt.title(" Superimposition Sine/Cosine curve")
plt.legend(['sine','cosine'])
plt.show()

# %% [markdown]
# 5. Plot Simple bar chart showing popularity of Programming Languages.
# Languages = ['Python', 'SQL', 'Java', 'C++', 'JavaScript']
# Popularity = [56, 39, 34, 34, 29]
# Security = [44 ,36 ,55, 50, 42]
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal
# bar chart using barh function.

# %%
Languages = ['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = np.array([56, 39, 34, 34, 29])
Security = np.array([44 ,36 ,55, 50, 42])
fig,(ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize = (10,10))
ax1.barh(Languages,Popularity,color= 'c')
ax1.set_title('Horizontal Bar plot of Popularity')
ax1.set_ylabel('Popularity')
ax2.bar(Languages,Security,color= 'm',edgecolor='black' )
ax2.set_title('Bar plot of Security')
ax2.set_ylabel('Security')
ax3.hist(Security,color= 'y',edgecolor='b' )
ax3.set_title('Histogram of Security')
ax3.set_xlabel('Bins')
ax3.set_ylabel('security')
fig.suptitle('Programming Languages', y = 1.05, fontsize=20)
# Out:
# Text(0.5, 1.05, 'Programming Languages')

# %% [markdown]
# 6. Plot Histogram, We have a sample data of Students marks of various Students, we will
# try to plot number of Students by marks range and try to figure out how many Students are
# average, below-average and Excellent.
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
# #Histogram showing Below Average, Average and Excellent distribution
# 40-60: Below Average 60-80: Average 80-100: Excellent

# %%
Marks = np.array([ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
ba= Marks[np.logical_and(Marks >= 40,Marks < 60)]
a = Marks[np.logical_and(Marks >= 60,Marks < 80)]
e = Marks[np.logical_and(Marks >= 80,Marks < 100)]
plt.figure(figsize=(10,10))
plt.hist(Marks, color='c', edgecolor='black')
plt.xlabel('Bins')
plt.ylabel('Marks')
plt.title('Marks in Histrogram')
plt.vlines([40, 60, 80,100], ymin=0, ymax=4, colors='k',linestyles=':')
plt.show()

# %%
bins = [40, 60, 80,100]
plt.figure(figsize=(8,5))
plt.hist(Marks, bins, color='pink', edgecolor='red')
plt.xlabel('Bins')
plt.ylabel('Marks')
plt.title('Histogram of Marks')
plt.show()
